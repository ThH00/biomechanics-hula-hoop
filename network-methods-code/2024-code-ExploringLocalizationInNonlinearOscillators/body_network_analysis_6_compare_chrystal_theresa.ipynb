# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
chrystal_data_wxy = np.load("chrystal_rotation_results/data_cc_w_xy.npy")
chrystal_data_psidot = np.load("chrystal_rotation_results/data_cc_psidot.npy")
# theresa_data_wxy = np.load("theresa_rotation_results/data_th_w_xy.npy")
theresa_data_psidot = np.load("theresa_rotation_results/data_th_psidot.npy")

# %% [markdown]
# ## Plot Data, $\dot{\psi}$

# %%
fig,ax = plt.subplots(figsize=(7,3))
print(f"{chrystal_data_psidot.shape=}")
ax.plot(chrystal_data_psidot[:,:,1]);
# Out:
# chrystal_data_psidot.shape=(1894, 10, 2)

# %%
fig,ax = plt.subplots(figsize=(7,3))
print(f"{theresa_data_psidot.shape=}")
ax.plot(theresa_data_psidot[:,1::2]);
# Out:
# theresa_data_psidot.shape=(1894, 20)

# %% [markdown]
# ## Plot Data, $\omega_{xy}$

# %%
fig,ax = plt.subplots(figsize=(7,3))
print(f"{chrystal_data_wxy.shape=}")
ax.plot(chrystal_data_wxy[:,:,1]);
# Out:
# chrystal_data_wxy.shape=(1894, 10, 2)

# %%
# fig,ax = plt.subplots(figsize=(7,3))
# print(f"{theresa_data_wxy.shape=}")
# ax.plot(theresa_data_wxy[:,1::2]);
